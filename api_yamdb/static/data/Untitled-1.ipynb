# %%
import pandas as pd
# Out:
# kek

# %%
df = pd.read_csv('titles.csv')
df
# Out:
#     id                                               name  year  category
# 0    1                                  Побег из Шоушенка  1994         1
# 1    2                                      Крестный отец  1972         1
# 2    3                             12 разгневанных мужчин  1957         1
# 3    4                                    Список Шиндлера  1993         1
# 4    5                                 Криминальное чтиво  1994         1
# 5    6                              Хороший, плохой, злой  1966         1
# 6    7                   Властелин колец: Братство кольца  2001         1
# 7    8                                    Бойцовский клуб  1999         1
# 8    9                                       Форрест Гамп  1994         1
# 9   10  Звёздные войны. Эпизод 5: Империя наносит отве...  1980         1
# 10  11                      Властелин колец: Две крепости  2002         1
# 11  12                                            Матрица  1999         1
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df = pd.read_csv('review.csv')

# %%
cnt =df.duplicated().sum()
# Out:
# 0

# %%
print(f'Количество дубликатов: '{df.du})
